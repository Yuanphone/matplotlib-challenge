# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# Based on the analysis of the two datasets provided, there are 249 mice assigned to 10 drugs' treatments. Over the course of 45 days, tumor development was observed and measured.
# 1. In the bar charts, the bar plots show the total number of timepoints for all mice tested for each drug regimen. The Capomulin has the most time point, and the Propriva has the least time point.
# 2. In the pie charts, the pie plots show the distribution of female and male mice. The female mice have 49.8% and the male mice have 50.2%. The male mice have one more than female mice (125 vs. 124).
# 3. In the part of quartiles, outliers and boxplots, the tumor volume for four drug regimens were analyzed. The result is that only one drug Infubinol has 1 outlier, and the number is 36.3213458.
# 4. In the line plot, the tumor volume and the time point for a mouse treated with Capomulin was negatively correlated. The time point increases and the tumor volume decreases.
# 5.In the scatter plot, the average tumor volume is positively correlated with mouse weight for the Capomulin regimen. The mouse weight increases and the average tumor volume increases.
# 6. The correlation coefficient is 0.88, which means there is a relatively strong positive relationship between the mouse weight and the average tumor volume. The r-squared for linear regression model is 0.70 which indicates that the model explains 70% of the variability of the response data around its mean. The average tumor volume could be predictable by using average weight of mouse.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sklearn import datasets
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mergedata=pd.merge(mouse_metadata,study_results, on="Mouse ID", how="outer")
# Display the data table for preview

mergedata
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
list(mergedata.columns)
# Out:
# ['Mouse ID',
#  'Drug Regimen',
#  'Sex',
#  'Age_months',
#  'Weight (g)',
#  'Timepoint',
#  'Tumor Volume (mm3)',
#  'Metastatic Sites']

# %%
# Checking the number of mice.
unique_mice=mergedata['Mouse ID'].unique()
count_mice=len(unique_mice)
count_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# The subset parameter is used for specifying the columns in which duplicates are to be searched
bool_mouseid=mergedata.duplicated(subset=['Mouse ID','Timepoint'], keep=False)
bool_mouseid
duplicated_mouseid=mergedata.loc[bool_mouseid,'Mouse ID'].unique()
duplicated_mouseid
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate = mergedata[bool_mouseid]
duplicate
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouseid=mergedata.duplicated(subset=['Mouse ID','Timepoint'],keep='first')
clean_data=mergedata[~clean_mouseid].reset_index()
# Using "keep='frist'", the dupcated rows are deleted
clean_data
# Out:
#       index Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0         0     k403     Ramicane  Male          21          16          0
# 1         1     k403     Ramicane  Male          21          16          5
# 2         2     k403     Ramicane  Male          21          16         10
# 3         3     k403     Ramicane  Male          21          16         15
# 4         4     k403     Ramicane  Male          21          16         20
# ...     ...      ...          ...   ...         ...         ...        ...
# 1883   1888     z969     Naftisol  Male           9          30         25
# 1884   1889     z969     Naftisol  Male           9          30         30
# 1885   1890     z969     Naftisol  Male           9          30         35
# 1886   1891     z969     Naftisol  Male           9          30         40
# 1887   1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_mouseid=clean_data['Mouse ID'].nunique()
number_mouseid
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# First Method to generate summary statistics
# Use groupby and summary statistical methods to calculate the following properties 
# of each drug regimen:mean, median, variance, standard deviation, and SEM of the tumor volume.

grouped_clean=clean_data.groupby("Drug Regimen")
mean_clean=grouped_clean["Tumor Volume (mm3)"].mean()
median_clean=grouped_clean["Tumor Volume (mm3)"].median()
variance_clean=grouped_clean["Tumor Volume (mm3)"].var()
std_clean=grouped_clean["Tumor Volume (mm3)"].std()
se_clean=grouped_clean["Tumor Volume (mm3)"].sem()
# Assemble the resulting series into a single summary dataframe.
summary_clean=pd.DataFrame({"Mean of Tumor Volume":mean_clean,\
            "Median of Tumor Volume":median_clean,"Variance of Tumor Volume":variance_clean,\
        "Std of Tumor Volume":std_clean,"SE of Tumor Volume":se_clean})
summary_clean
# Out:
#               Mean of Tumor Volume  Median of Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741               41.557809
# Ceftamin                 52.591172               51.776157
# Infubinol                52.884795               51.820584
# Ketapril                 55.235638               53.698743
# Naftisol                 54.331565               52.509285
# Placebo                  54.033581               52.288934
# Propriva                 52.393463               50.909965
# Ramicane                 40.216745               40.673236
# Stelasyn                 54.233149               52.431737
# Zoniferol                53.236507               51.818479
#
#               Variance of Tumor Volume  Std of Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764             4.994774
# Ceftamin                     39.290177             6.268188
# Infubinol                    43.128684             6.567243
# ...

# %%
#The second method:
# Using the aggregation method, produce the same summary statistics in a single line
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_agg=grouped_clean["Tumor Volume (mm3)"].agg(['mean','median','var','std','sem'])
summary_rename=summary_agg.rename(columns={"mean":"Mean of Tumor Volume","median": "Median of Tumor Volume",\
                                "var":"Variance of Tumor Volume","std": "Std of Tumor Volume",\
                                          "sem":"SE of Tumor Volume"})
summary_rename
# Out:
#               Mean of Tumor Volume  Median of Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741               41.557809
# Ceftamin                 52.591172               51.776157
# Infubinol                52.884795               51.820584
# Ketapril                 55.235638               53.698743
# Naftisol                 54.331565               52.509285
# Placebo                  54.033581               52.288934
# Propriva                 52.393463               50.909965
# Ramicane                 40.216745               40.673236
# Stelasyn                 54.233149               52.431737
# Zoniferol                53.236507               51.818479
#
#               Variance of Tumor Volume  Std of Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764             4.994774
# Ceftamin                     39.290177             6.268188
# Infubinol                    43.128684             6.567243
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints 
#for all mice tested for each drug regimen using Pandas.

total_timepoints=grouped_clean["Timepoint"].sum()

reset_timepoint=total_timepoints.reset_index()
set_timepoint=reset_timepoint.set_index("Drug Regimen")
set_timepoint
# Out:
#               Timepoint
# Drug Regimen
# Capomulin          4960
# Ceftamin           3515
# Infubinol          3235
# Ketapril           3705
# Naftisol           3650
# Placebo            3380
# Propriva           2665
# Ramicane           4885
# Stelasyn           3480
# Zoniferol          3525

# %%
set_timepoint.plot(kind="bar",figsize=(8,4),rot=45)
plt.title("Total Number of Timepoints for Each Drug Regimen")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for 
# all mice tested for each drug regimen using pyplot.
# set x axis and tick locations
x_axis=np.arange(len(set_timepoint))
tick_locations=[value for value in x_axis]
# figuresize:width hight
plt.figure(figsize=(8,4))
plt.bar(x_axis,reset_timepoint["Timepoint"],color='r',alpha=0.5,align='center')
plt.xticks(tick_locations,reset_timepoint["Drug Regimen"], rotation=45)
# set x and y limits
plt.xlim(-0.75,len(x_axis))
plt.ylim(0,max(reset_timepoint["Timepoint"])+1000)
# set a time and lables
plt.title("Total Number of Timepoints for Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Total number of Timepoints")
#Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/totaltimepoint_drug.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_grouped=clean_data.groupby("Mouse ID")["Sex"].value_counts()
gender_grouped
# Out:
# Mouse ID  Sex
# a203      Female    10
# a251      Female    10
# a262      Female    10
# a275      Female    10
# a366      Female     7
#                     ..
# z435      Female     3
# z578      Male      10
# z581      Female    10
# z795      Female    10
# z969      Male      10
# Name: Sex, Length: 249, dtype: int64

# %%
gendercount_grouped=gender_grouped.groupby("Sex").count()
gendercount_grouped
gender_table=pd.DataFrame({"Counts":gendercount_grouped})
gender_table
# Out:
#         Counts
# Sex
# Female     124
# Male       125

# %%
reset_gender=gender_table.reset_index()
reset_gender
# Out:
#       Sex  Counts
# 0  Female     124
# 1    Male     125

# %%
#using Pandas
gender_pie=gender_table.plot(kind="pie",y="Counts", autopct='%1.1f%%', startangle=45,shadow=True,
                     colors=["pink","blue"],
                             fontsize=17,title="The Distribution of Female versus Male Mice")
gender_pie.set_ylabel("Percentage of Gender")
plt.axis("equal")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.title("The Distribution of Female versus Male Mice")
plt.pie(reset_gender["Counts"],labels=reset_gender["Sex"],autopct='%1.1f%%', startangle=45,
        shadow=True,colors=["pink","blue"])
plt.axis("equal")
plt.ylabel('Percentage of Gender')
plt.savefig("Images/Pypies.png")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
grouped_last=clean_data.groupby(['Drug Regimen','Mouse ID']).last()[['Timepoint','Tumor Volume (mm3)']]
grouped_last
final_tumorvol =grouped_last.reset_index()

final_tumorvol
# Out:
#     Drug Regimen Mouse ID  Timepoint  Tumor Volume (mm3)
# 0      Capomulin     b128         45           38.982878
# 1      Capomulin     b742         45           38.939633
# 2      Capomulin     f966         20           30.485985
# 3      Capomulin     g288         45           37.074024
# 4      Capomulin     g316         45           40.159220
# ..           ...      ...        ...                 ...
# 244    Zoniferol     q633         45           70.827796
# 245    Zoniferol     s337         45           62.109651
# 246    Zoniferol     w140          5           47.717952
# 247    Zoniferol     w575         45           68.401286
# 248    Zoniferol     x613         15           48.077646
#
# [249 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments=['Capomulin','Ramicane','Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumorvol=[]
for drug in treatments:
    vol=final_tumorvol.loc[final_tumorvol['Drug Regimen']==drug,'Tumor Volume (mm3)']
    tumorvol.append(vol)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    quartiles=vol.quantile([.25,.5,.75])
    lowerq=quartiles[0.25]
    upperq=quartiles[0.75]
    iqr=upperq-lowerq
    print(f"{drug} Regimen")
    print(f"The lower quartile of tumorvol is:{lowerq}")
    print(f"The upper quartile of tumorvol is:{upperq}")
    print(f"The interquartile range of tumorvol is:{iqr}")
    print(f"The median quartile of tumorvol is:{quartiles[0.5]}")
    lower_bound=lowerq-(1.5*iqr)
    upper_bound=upperq+(1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    outliers=vol.loc[(vol<lower_bound)|(vol>upper_bound)]
    print(f'the number of outlier for {drug} is {outliers.count()}')
    if outliers.count()> 0:
         for i in outliers.index:
            print(f'the potential outlier for {drug} is {outliers[i]}')
# Out:
# Capomulin Regimen
# The lower quartile of tumorvol is:32.37735684
# The upper quartile of tumorvol is:40.1592203
# The interquartile range of tumorvol is:7.781863460000004
# The median quartile of tumorvol is:38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# the number of outlier for Capomulin is 0
# Ramicane Regimen
# The lower quartile of tumorvol is:31.56046955
# The upper quartile of tumorvol is:40.65900627
# The interquartile range of tumorvol is:9.098536719999998
# The median quartile of tumorvol is:36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.
# the number of outlier for Ramicane is 0
# Infubinol Regimen
# The lower quartile of tumorvol is:54.04860769
# The upper quartile of tumorvol is:65.52574285
# The interquartile range of tumorvol is:11.477135160000003
# The median quartile of tumorvol is:60.16518046
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# fig1, final_tumor_plot = plt.subplots()

fig1, ax1 = plt.subplots()
ax1.boxplot(tumorvol, labels=treatments)
ax1.set_title('Drug Regimen')
ax1.set_ylabel('Final Tumor Volume')
plt.savefig("Images/boxplot.png")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Capomulin_data_id=clean_data[clean_data["Drug Regimen"]=="Capomulin"]["Mouse ID"].unique()
Capomulin_data_id
# Out:
# array(['s185', 'x401', 'm601', 'f966', 'u364', 'y793', 'r554', 'm957',
#        't565', 'i738', 'w914', 'g288', 'l897', 'b742', 'b128', 'j246',
#        'j119', 'w150', 'v923', 'g316', 's710', 'l509', 'r944', 'i557',
#        'r157'], dtype=object)

# %%
# Select a mouseid treated with capomulin
mouseid='j246'
j246_vol=clean_data[clean_data["Mouse ID"]=="j246"]["Tumor Volume (mm3)"]
j246_timepoint=clean_data[clean_data["Mouse ID"]=="j246"]["Timepoint"]

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
plt.plot(j246_timepoint,j246_vol,marker="o",color="red",linewidth=1)
plt.title("Tumor Volume vs. Time Point")
plt.xlabel("Time Point'")
plt.ylabel("Tumor Volume")
plt.grid()
plt.savefig("Images/lineplot.png")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
Capomulin_data=clean_data[clean_data["Drug Regimen"]=="Capomulin"]
ave_weight=Capomulin_data.groupby("Mouse ID")["Weight (g)"].mean()
ave_vol=Capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
plt.scatter(ave_weight,ave_vol,marker="o",color="red")
plt.title("Average Tumor Volume vs. Mouse Weight for the Capomul in Regimen")
plt.xlabel("Average Mouse Weight")
plt.ylabel("Average Tumor Volume")
plt.savefig("Images/scatterplot.png")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(ave_weight,ave_vol)
print(f'The correlation coefficient between mouse weight and average tumor volume is {correlation}')
# Out:
# The correlation coefficient between mouse weight and average tumor volume is (0.841936342469472, 1.3225722434712483e-07)

# %%
#linear regression model
x_values=ave_weight
y_values=ave_vol
#using lingress from scipy.stats
(slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
regress_values=x_values*slope+intercept
#makeing a text version o four equation
line_eq="y="+str(round(slope,2))+"x+"+str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,36), fontsize=15, color="red")
# plt.annotate(line_eq,(5.8,0.8), frontsize=15,color="red")
plt.xlabel("Average Mouse Weight")
plt.ylabel("Average Tumor Volume")
print(f"The r-squared is :{rvalue**2}")
plt.savefig("Images/linearregression.png")
plt.show()
# Out:
# The r-squared is :0.7088568047708723
